# %%
a,b= map(float,input().split())
print('chu vi',(a+b)*2)
print('dien tich',a*b)
# Out:
# chu vi 22
# dien tich 30

# %%
a=float(input())
print ('chu vi',2*a*3.14)
print ('dien tich',a*a*3.14)
# Out:
# chu vi 6.28
# dien tich 3.14

# %%
a,b,c=map(float,input().split())
if a+b-c>0 and a+c-b>0 and b+c-a>0 :
    if a==b and b==c :
        print ('tam giac dieu')
    elif (a**2+b**2)==c**2 or (b**2+c**2)==a**2 or (a**2+c**2)==b**2 :
        print('tam giac vuong')
    elif (a==b and a!=c) or (a==c and a!=b) or (b==c and b!=a):
        print ('tam giac can')
    else :
        print('tam giac thuong')
    t=a+b+c
    k=t/2
    s=(k*(k-a)*(k-b)*(k-c))**0.5
    print ('chu vi',t)
    print ('dien tich',f"{s:.2f}")
else :
    print (' k phai ba canh tam giac')
# Out:
#  k phai ba canh tam giac

# %%
a,b=map(float,input().split())
if a!=0 :
    if b!=0:
        x=-b/a
        print ('nghiem la',f"{x:.2f}")
    else :
        print ('nghiem la 0')
else :
    if b==0:
        print('phuong trinh vo so nghiem')
    else :
        print (' phuong trinh k co nghiem')
# Out:
# nghiem la 0

# %%
a,b,c=map(float,input().split())
if a==0:
    if b!=0 :
        x=-c/b
        print ('nghiem la',f"{x:.2f}")
    else :
        if c==0:
            print('phuong trinh vo so nghiem')
        else :
            print (' phuong trinh vo nghiem')
else :
    t=b**2-4*a*c
    if t>0 :
        x1=(-b+t**0.5)/(2*a)
        x2=(-b-t**0.5)/(2*a)
        print ('phuong trin co nghiem',x1)
        print ('phuong trin co nghiem',x2)
    elif t==0:
        x=(-b-t**0.5)/(2*a)
        print ('phuong trin co nghiem',x)
    else :
        print ('phuong trinh vo nghiem ')
# Out:
# phuowng trinh vo nghiem

# %%
s=input().split()
m=int(s[0])
for i in range(len(s)) :
    if int(s[i])>m :
        m=int(s[i])
print('so lon nhat',m)
# Out:
# so lon nhat 9

# %%
s=input().split()
m=int(s[0])
for i in range(len(s)) :
    if int(s[i])<m :
        m=int(s[i])
print('so nho nhat',m)
# Out:
# so nho nhat 1

# %%
a,b,c,d,m,n=map(float,input().split())
if a!=0 and b!=0 and c!=0 and d!=0 :
    if a/c==b/d and a/c==m/n :
        print('phuong trinh vo so nghiem')
    elif a/c== b/d and a/c!=m/n :
        print('phuong trinh vo nghiem')
    else  :
        y=(m*c-n*a)/(b*c-a*d)
        x=(m-b*y)/a
        print (x,y)
# Out:
#   Cell In[6], line 13
#
#     ^
# _IncompleteInputError: incomplete input

# %%
n=int(input())
h=n//3600
n=n%3600
k=n//60
n=n%60
print(h,'gio',k,'phut',n,'giay')
# Out:
# 1 gio 0 phut 0 giay

# %%
a,b,r,x,y=map(float,input().split())
if ((x-a)**2+(y-b)**2)==r**2 :
    print('thuoc duong tron')
else :
    print('k thuoc duong tron')
# Out:
# thuoc duong tron

# %%
x,y=map(int,input().split())
print(x**y)
# Out:
# 8
