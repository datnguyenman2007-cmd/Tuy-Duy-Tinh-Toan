# %% [markdown]
# Viết một chương trình nhập vào một số nguyên n và in ra các chữ số đảo ngược nhau.

# %%
n = input()
print(n[::-1])
# Out:
# 431

# %% [markdown]
# Hoán đổi hai số không sd biến tạm thời
# Sử dụng phép toán XOR bitwise để hoán đổi giá trị của hai biến.

# %%
a,b = map(int,input().split())
x = a ^ b
b = x ^ b
a = x ^ a
print(a,b)
# Out:
# 11 10

# %% [markdown]
# Kiểm tra xem một số có phải là lũy thừa của 2 hay không
# Sử dụng các toán tử bitwise để xác định xem một số có phải là lũy thừa của 2 hay không.

# %%
a = int(input())    
if a & (a - 1) == 0:
    print("true")
else:
    print("false")
# Out:
# true

# %% [markdown]
# viêt chương trình chia một số m cho n, kết quả thu được làm tròn xuống

# %%
m,n = map(int,input().split())
print(m//n)
# Out:
# 51

# %% [markdown]
# viêt chương trình chia một số m cho n, kết quả thu được làm tròn lên

# %%
m,n = map(int,input().split())
print(m//n + 1)
# Out:
# 52

# %% [markdown]
# [Even and Odd]
# Nhập vào một số nguyên dương x, bạn hãy kiểm tra xem x là số chẵn hay lẻ. Nếu x là số chẵn, in ra "Even". Nếu x
# là số lẻ, in ra "Odd".

# %%
x = int(input())
if x%2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Even

# %% [markdown]
# [Check negative numbers]
# Nhập vào hai số nguyên a, b. Nếu cả hai số a, b đều âm thì in ra "Yes", ngược lại in ra "No".

# %%
a = int(input())
b = int(input())
if a < 0 and b < 0:
    print("Yes")
else:
    print("No")
# Out:
# No

# %% [markdown]
# [Longer string]
# Nhập vào hai chuỗi a, b gồm các chữ cái thường. In ra "True" nếu chuỗi a dài hơn chuỗi b. Ngược lại in ra "False".

# %%
a = input()
b = input()
if len(a) > len(b):
    print("true")
else:
    print("false")
# Out:
# true

# %% [markdown]
# [Triangle]
# Nhập vào 3 số nguyên dương a, b, c. Kiểm tra xem a, b, c có cấu thành độ dài cạnh của 1 tam giác được không.
# Nếu a, b, c cấu tạo thành được một tam giác, in ra "Yes". Ngược lại in ra "No".

# %%
a = int(input())
b = int(input())
c = int(input())
if a + b > c and b + c > a and a + c > b:
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %% [markdown]
# Nhập vào 4 số nguyên. In ra màn hình số nguyên lớn nhất trong 4 số.

# %%
a = int(input())
b = int(input())
c = int(input())
d = int(input())
x = max(a,b,c,d)
print(x)
# Out:
# 3123

# %% [markdown]
# [Phân loại tam giác]
# Nhập vào 3 số nguyên dương a,b,c là độ dài 3 cạnh của một tam giác. Kiểm tra 3 số đã nhập có tạo thành một tam giác hợp
# lệ hay không. Nếu không in ra "Không phải tam giác". Nếu có, phân loại tam giác đó là "Tam giác đều", "Tam giác cân", hay
# "Tam giác thường".

# %%
a,b,c = map(int,input().split())
if a + b > c and b + c > a and a + c > b:
    if a == b and b == c:
        print("Tam giác đều")
    elif a == b or b == c or a == c:
        print("Tam giác cân")
    else:
        print("Tam giác thường")
else:
    print("Không phải tam giác")
# Out:
# Không phải tam giác

# %% [markdown]
# [Kiểm tra năm nhuận]
# Nhập vào một số nguyên dương n là số năm, kiểm tra xem năm đó có phải là năm nhuận hay không. Năm nhuận là năm
# chia hết cho 4 nhưng không chia hết cho 100, hoặc chia hết cho 400. Nếu là năm nhuận in ra "Yes", nếu không in ra "No"

# %%
a = int(input())
if a%4 == 0 and a%100 != 0:
    print("Yes")
elif a%400 == 0:
    print("Yes")
else:
    print("No")
# Out:
# No

# %% [markdown]
# [Tính tiền điện]
# Nhập vào số kWh điện tiêu thụ. Tính tiền điện theo các bậc sau: - 0-50 kWh: 1500đ/kWh - 51-100 kWh: 2000đ/kWh - 100 kWh: 3000đ/

# %%
a = int(input())
if a <= 50:
    x = a * 1500
elif 50 < a and a <= 100:
    x = 50 * 1500 + (a - 50)*2000
elif 100 < a:
    x = 50 * 1500 + 50 * 2000 + (a - 100)*3000
print(x)
# Out:
# 175000

# %% [markdown]
# [Giải phương trình bậc nhất]
# Nhập vào hai số thực a và b của phương trình ax + b = 0. Tìm và in ra nghiệm của phương trình, kết quả làm tròn đến số
# thập phân thứ 2. In ra "Vô nghiệm" hoặc "Vô số nghiệm" trong trường hợp tương ứng.

# %%
a = float(input())
b = float(input())
if a != 0 and b != 0:
    x = -b/a
elif a == 0:
    if b == 0:
        print("Vô số nghiệm")
    else:
        print("vô nghiệm")
print(f"{x:.2f}")
# Out:
# -430.87

# %% [markdown]
# [Xếp loại học lực]
# Nhập vào điểm trung bình của một học sinh và in ra học lực của học sinh đó. Xếp loại học lực theo quy tắc: - >= 8.0: Giỏi - >= 6.5: Khá - >= 5.0: Trung bình - < 5.0: Yế

# %%
a = float(input())
if a >= 8.0:
    print("Giỏi")
elif a >= 6.5:
    print("Khá")
elif a >= 5.0:
    print("Trung bình")
else:
    print("Yếu")
# Out:
# Giỏi

# %% [markdown]
# [Rounding]
# Nhập vào một số thực: in ra kết quả làm tròn lên ,tròn xuống, làm tròn tới số nguyên gần nhất (không được sử dụng hàm
# sẵn có của pyton). Các kết quả cách nhau một dấu cách

# %%
a = float(input())
b = a // 1
if a > 0:
    c = b + 0.5
    d = b + 1
    if a >= c:
        print(d,b,d)
    else:
        print(d,b,b)
elif a == b:
    print(a,a,a)
elif a < 0:
    c = b - 0.5
    d = b + 1
    if a >= c:
        print(d,b,b)
    else:
        print(d,b,d)
# Out:
# -7.0 -8.0 -8.0

# %% [markdown]
# Cấp số nhân
# Cho 4 số a, b, c, d. Hãy kiểm tra xem 4 số này có thể theo thứ tự tạo thành 1 cấp số nhân với công bội nguyên theo đúng
# thứ tự a, b, c, d hay không?
# Gợi ý : Tìm công bội (b / a) nếu b chia hết cho a, sau đó lấy b nhân công bội và so sánh vs c, c nhân công bội và so sánh vs
# d.

# %%
a,b,c,d = map(int,input().split())
x = b/a
y = b*x
z = c*x
if x % 1 != 0:
    print("NO")
if y == c and z == d:
    print("YES")
else:
    print("NO")
# Out:
# NO
