# %%
n=int(input())
print(n*2)

# %%
a,b =map(int,input().split())
pi=3.14
t=a*b-((a/2)**2)*pi
print(round(t,2))

# %%
a=str(input())
if a.isupper() :
    print(a.lower())
else :
    print (a.upper())
# Out:
# a

# %%
a,b,c=map(int,input().split())
if a+b-c>0:
     if a+c-b>0 :
         if b+c-a>0 :
            p=(a+b+c)/2
            s=(p*(p-a)*(p-b)*(p-c))**(1/2)
            print(round(s,1))
else :
    print('k phai 3 canh tam giac ')
# Out:
# k phai 3 canh tam giac

# %%
s=input()
if len(s)>=20:
    a=s[4]
    b=s[8]
    print(a,b)
else :
    print('k do dai')
# Out:
# b k

# %%
a=input()
b,c=map(int,input().split())
k=c-b
if k<=50 :
    t=k*1984    
elif k>50 and k<=100:
    t=50*1984+(k-50)*2050
elif k>100 and k<=200:
    t=50*1984+50*2050+(k-100)*2380
elif k>200 and k<=300:
    t=50*1984+50*2050+100*2380+(k-200)*2998
elif k>300 and k<=400:
    t=50*1984+50*2005+100*2380+100*2998+(k-300)*3350
elif k>400:
    t=50*1984+50*2050+100*2380+100*2998+100*3350+(k-400)*3460
h=t*1.08
print('so tien ',a,'phai tra la',f"{h:.0f}")
# Out:
# so tien  a phai tra la 1855505

# %% [markdown]
# bai tap khac

# %%
n=int(input())
if n%2==0 :
    print(n,'so chan')
else :
    print(n,'la so le')
# Out:
# 10 so chan

# %%
n=int(input())
if n%10==5 :
    print('True')
else :
    print('False')
# Out:
# False

# %%
n=int(input())
if n%3==0 and n%5==0 :
    print('True')
else :
    print('False')
# Out:
# False

# %%
n=int(input())
if (2026-n)>=18 :
    print('Du tuoi bau cu')
else :
    print('k du tuoi bau cu')
# Out:
# Du tuoi bau cu

# %%
a,b=map(int, input().split())
if a>b :
    print(a,'lon hon',b)
if a<b:
    print(b,'lon hon',a)
if a==b :
    print ('hai so bang nhau')
# Out:
# 20 lon hon 10

# %%
k=float(input())
if k<5 :
    print('yeu') 
elif k>=5 and k<6.5:
    print('trung binh') 
elif k>=6.5 and k<8:
   print('kha') 
elif k>=8:
    print('gioi')
# Out:
# kha

# %%
n=float(input())
if n>=4 :
    print('qua mon')
else :
    print('hoc lai')
# Out:
# qua mon

# %%
n=int(input())
if (2025-n)>=18 :
    print('Du 18 tuoi')
else :
    print('chua du 18 tuoi')
# Out:
# Du 18 tuoi
