# %%
n=int(input())
print(n*2)

# %%
a,b =map(int,input().split())
pi=3.14
t=a*b-((a/2)**2)*pi
print(round(t,2))

# %%
a=str(input())
if a.isupper() :
    print(a.lower())
else :
    print (a.upper())
# Out:
# a

# %%
a,b,c=map(int,input().split())
if a+b-c>0:
     if a+c-b>0 :
         if b+c-a>0 :
            p=(a+b+c)/2
            s=(p*(p-a)*(p-b)*(p-c))**(1/2)
            print(round(s,1))
else :
    print('k phai 3 canh tam giac ')
# Out:
# k phai 3 canh tam giac
