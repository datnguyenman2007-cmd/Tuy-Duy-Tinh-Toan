# %% [markdown]
# Viết chương trình Python sử dụng một trong 2 loại vòng lặp for hoặc while để
# tính tống các số nguyên từ 1 đến n. (n <= 1000)

# %%
#bai1
n=int(input())
tong=0
for i in range (n+1):
    tong+=i
print(tong)
# Out:
# 405450

# %% [markdown]
# VIết chương trình nhập vào một số tới khi được một số nguyên dương thì thôi.
# Kiểm tra số này có phải là số nguyên tố hay không?

# %%
#bai2
n=int(input())
a=0
if n<0 :
    print("nhap so nguyen duong")
else:
    for i in range (n):
        if n%(i+1)==0:
            a=a+1
if a==2:
    print("la so nguyen to")
else:
    print("ko phai so nguyen to")
# Out:
# la so nguyen to

# %% [markdown]
# Viết chương trình tính giai thừa của một số nguyên n cho trước (n!=1×2×…×n)
# với 0 < n < 100.

# %%
#bai3
n=int(input())
t=1
for i in range(1,n+1,1) :
    t=t*i
print(t)
# Out:
# 120

# %% [markdown]
# Viết chương trình nhập vào một số nguyên n và in ra màn hình số chữ số (trừ dấu)
# của số đó. Không dùng kiểu dữ liệu string

# %%
#bai4
x=int(input())
if x==0 :
    print('1')  
else : 
    d1=0 
    while x>0 :
        d1=d1+1
        x=x//10
    print(d1)
# Out:
# 5

# %% [markdown]
# Hãy viết một chương trình nhận vào một số nguyên dương n và một dãy gồm n số
# nguyên. Nếu n số nguyên đó có số 42 thì in ra màn hình dòng chữ "I′ve found the
# meaning of life!", ngược lại in ra dòng chữ "It′s a joke!".

# %%
#bai5
n=int(input())
a=list(map(int,input().split()))
if 42 in a :
    print('I′ve found the meaning of life!')
else :
    print('It′s a joke!')
# Out:
# 1

# %% [markdown]
# Nhập hai số nguyên dương a, b (a ≤ b). Hãy tính tổng các số nguyên tố trong đoạn
# [a, b]. Mỗi dòng là một bộ test (a b).

# %%
#bai6
a,b=map(int,input().split())
t=0
for i in range(a,b+1,1) :
    d=0
    for j in range(1,i+1,1) :
        if i%j==0 :
            d=d+1
    if d==2 :
        t=t+i
print(t)
# Out:
# 10

# %% [markdown]
# Nhập vào số nguyên dương n (n ≥ 2). Hãy in ra ước số nguyên tố lớn nhất của n."

# %%
#bai7
n=int(input())
for i in range (1,n+1,1):
    d=0
    if n%i==0:
        for j in range(1,i+1):
            if i%j==0:
                d=d+1
        if d==2 :
            max=i
print(max)
# Out:
# 5

# %% [markdown]
# Nhập số nguyên dương n. Lặp lại phép toán n = n + reverse(n) cho đến khi n là số
# đối xứng (palindrome). In ra số bước và giá trị palindrome thu được.

# %%
#bai8
n=input()
x=int(n)
if x<10:
    print(n)
    print("0")
else:
    d=0
    while str(x)!=n[::-1] :
        x=x+int(n[::-1])
        d=d+1
        n=str(x)
    print(n)
    print(d)
# Out:
# 46177164
# 8

# %% [markdown]
# Bai 9 Nhập vào số nguyên dương n. In ra tất cả các số chính phương ≤ n có các chữ số
# đôi một khác nhau (in theo thứ tự tăng dần, cùng hàng, cách nhau bởi một dấu
# cách). Nếu không có, in ra (no number)

# %%
#cach 1
n=int(input())
def cp(k) :
    d=0
    for i in range(1,k+1) :
        if k==i*i :
            d=d+1
    if d==1 :
            return True
    else :
            return False

for i in range(2,n):
    if cp(i)==True :
        k=str(i)
        if len(k)==len(set(k)):
            print(k,end=' ')
# Out:
# 4 9 16 25 36 49 64 81 169 196 256 289 324 361 529 576 625 729 784 841 961

# %%
#cach 2
n=int(input())
i=2
while i*i<=n:
    k=str(i*i)
    if len(k)==len(set(k)):
        print(i*i,end=' ')
    i=i+1
# Out:
# 4 9 16 25 36 49 64 81 169 196 256 289 324 361 529 576 625 729 784 841 961

# %% [markdown]
# Bai 10 Nhập vào số nguyên dương n. Tìm số x trong [1, n] có độ dài dãy Collatz lớn nhất
# và in ra x cùng độ dài dãy tương ứng (x L). Nếu có nhiều số cùng độ dài, chọn số
# nhỏ nhất."

# %% [markdown]
# Bai 11 Viết chương trình đếm số lượng ước số chẵn của số nguyên dương n với n < 10^6.

# %%
n=int(input())
d=0
for i in range(1,n+1):
    if n%i==0 and i%2==0 :
        d=d+1
print(d)
# Out:
# 4

# %% [markdown]
# Bai 12 Một người có tài khoản tiết kiệm ở ngân hàng và gửi vào X đồng với lãi suất là
# 0.7% mỗi tháng. Viết chương trình tính số tiền sau N tháng người ấy rút được (cả
# gốc và lãi, bỏ qua phần lẻ thập phân).

# %%
n=float(input())
k=int(input())
t=n*(1.007)*k
print(f"{t:.0f}")
# Out:
# 2014

# %% [markdown]
# Bai 13 Hai số nguyên dương tạo thành một cặp số thân thiết khi chúng tuân theo quy luật:
# Số này bằng tổng tất cả các ước của số kia (trừ chính nó) và ngược lại.
# Ví dụ 220 và 284 là một cặp số thân thiết
# 220 ngoài chính nó ra, nó còn có 11 ước số khác là: 1, 2, 4, 5, 10, 11, 20, 44, 55,
# 110. Tổng của 11 ước này cho chúng ta 284
# 284 ngoài bản thân nó, còn có 5 ước số khác là: 1, 2, 4, 71, 142. Tổng của chúng
# vừa đúng bằng 220
# Nhập hai số từ bàn phím và kiểm tra xem chúng có phải là cặp số thân thiết không.
# Nếu có, in ra màn hình "true", ngược lại, in ra "false"

# %%
m,n=map(int,input().split())
t1=0
t2=0
for i in range(1,m) :
    if m%i==0 :
        t1=t1+i
        
for i in range(1,n) :
    if n%i==0 :
        t2=t2+i
       
if t1==n and t2==m :
    print('true')
else :
    print('false')
# Out:
# true

# %% [markdown]
# Bai 14 Cho hai số m và n là hai số nguyên dương nhập từ bàn phím. Viết chương trình
# tìm ước chung lớn nhất của hai số m và n.

# %%
m,n=map(int,input().split())
if m<=n :
    for i in range(m,1,-1) :
        if m%i==0 and n%i==0:
            print(i)
            break
            
            
else :
    for i in range(n,1,-1) :
        if m%i==0 and n%i==0:
            print(i)
            break
# Out:
# 6

# %% [markdown]
# Bai 15 [ChickenAndDog]
# "Vừa gà vừa chó,
# Bó lại cho tròn,
# Ba mươi sáu con,
# Một trăm chân chẵn"
# Từ bài toán dân gian trên, mở rộng thành chương trình nhận đầu vào là tổng số
# con và tổng số chân của gà và chó. Nếu tìm được số phù hợp, in ra số lượng gà và
# số lượng chó. Ngược lại, in ra "invalid".

# %%
d=0
for i in range(1,36):
    if (i*2+(36-i)*4)==100 :
        print(i,'co ga')
        print(36-i,'co cho')
        d=d+1
if d!=1:
        print('invalid')
# Out:
# 22 co ga
# 14 co cho
