# %%
n=int(input())
i=int(str(n)[::-1])
print(i)
# Out:
# 987654

# %%
x=input()
y=input()
x,y=y,x
print(x)
print(y)
# Out:
# dhr
# huy fjd

# %%
n=int(input())
if n&(n-1)==0:
    print("la luy thua cua 2")
else: print("ko phai luy thua cua 2")
# Out:
# la luy thua cua 2

# %%
m,n=map(int,input().split())
x=m/n
print(x//1)
# Out:
# 1.0

# %%
m,n=map(int,input().split())
x=m/n
print(round(x,2))
# Out:
# 1.25

# %%
n=int(input())
if n%2==0:
    print("EVEN")
else:print("ODD")
# Out:
# ODD

# %%
m,n=map(int,input().split())
if m<=0 and n<=0:
    print("YES")
else:print("NO")
# Out:
# NO

# %%
m,n=input().split()
x=len(m)
y=len(n)
if x>y:
    print("TRUE")
else:print("FALSE")
# Out:
# FALSE

# %%
a,b,c=map(int,input().split())
if a+b>c and b+c>a and a+c>b :
    print('Yes')
else :
    print ('No')
# Out:
# No

# %%
s=input().split()
m=int(s[0])
for i in range(len(s)) :
    if int(s[i])>m :
        m=int(s[i])
print('so lon nhat',m)
# Out:
# so lon nhat 9

# %%
a,b,c=map(float,input().split())
if a+b-c>0 and a+c-b>0 and b+c-a>0 :
    if a==b and b==c :
        print ('tam giac dieu')
    elif (a**2+b**2)==c**2 or (b**2+c**2)==a**2 or (a**2+c**2)==b**2 :
        print('tam giac vuong')
    elif (a==b and a!=c) or (a==c and a!=b) or (b==c and b!=a):
        print ('tam giac can')
    else :
        print('tam giac thuong')
else :
    print('khong hop le')
# Out:
# tam giac dieu

# %%
n=int(input())
if (n%4==0 and n%100!=0 ) or n%400==0:
    print('năm nhuan')
else :
    print('năm k nhuan')
# Out:
# năm k nhuan

# %%
k=int(input())
if k<=50 :
    t=k*1500    
elif k>50 and k<=100:
    t=50*1500+(k-50)*2000
elif k>100 :
    t=50*1500+50*2000+(k-100)*3000
print('so tien phai tra la',t)
# Out:
# so tien phai tra la 60000

# %%
a,b=map(float,input().split())
if a!=0 :
    if b!=0:
        x=-b/a
        print ('nghiem la',f"{x:.2f}")
    else :
        print ('nghiem la 0')
else :
    if b==0:
        print('phuong trinh vo so nghiem')
    else :
        print (' phuong trinh k co nghiem')

# %%
k=float(input())
if k<5 :
    print('yeu') 
elif k>=5 and k<6.5:
    print('trung binh') 
elif k>=6.5 and k<8:
   print('kha') 
elif k>=8:
    print('gioi')
